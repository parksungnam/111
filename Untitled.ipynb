# %%
df = pd.read_excel('주석.xlsx')
df
# Out:
#                                                    주석 Unnamed: 1
# 0                            제 3(당)기 2023년 12월 31일 현재        NaN
# 1                            제 2(전)기 2022년 12월 31일 현재        NaN
# 2                                          재단법인 김포에프씨        NaN
# 3                                                 NaN        NaN
# 4                                1. 재단법인의 개황 및 주요사업내용        NaN
# 5                                                 NaN        NaN
# 6   재단법인 김포에프씨(이하 "재단")은 김포시 김포FC 설립 및 운영 조례의 규정에 ...        NaN
# 7                                                 NaN        NaN
# 8     재단의 기본재산은 김포시청이 출연하였으며, 재단의 주요사업 내용은 다음과 같습 니다.        NaN
# 9                                                 NaN        NaN
# 10                               (1) 김포FC 축구단 운영 및 지원        NaN
# 11                (2) 유소년 축구교실 운영을 통한 지역의 축구 꿈나무 육성사업        NaN
# 12               (3) 지역 연고의 정착을 통한 지역 홍보 및 스포츠 마케팅 사업        NaN
# ...

# %%
df
# Out:
#                                                    주석 Unnamed: 1
# 0                            제 3(당)기 2023년 12월 31일 현재        NaN
# 1                            제 2(전)기 2022년 12월 31일 현재        NaN
# 2                                          재단법인 김포에프씨        NaN
# 3                                                 NaN        NaN
# 4                                1. 재단법인의 개황 및 주요사업내용        NaN
# 5                                                 NaN        NaN
# 6   재단법인 김포에프씨(이하 "재단")은 김포시 김포FC 설립 및 운영 조례의 규정에 ...        NaN
# 7                                                 NaN        NaN
# 8     재단의 기본재산은 김포시청이 출연하였으며, 재단의 주요사업 내용은 다음과 같습 니다.        NaN
# 9                                                 NaN        NaN
# 10                               (1) 김포FC 축구단 운영 및 지원        NaN
# 11                (2) 유소년 축구교실 운영을 통한 지역의 축구 꿈나무 육성사업        NaN
# 12               (3) 지역 연고의 정착을 통한 지역 홍보 및 스포츠 마케팅 사업        NaN
# ...

# %%
df.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b86d0">
#   <thead>
#     <tr>
#       <th id="T_b86d0_level0_col0" class="col_heading level0 col0" >주석</th>
#       <th id="T_b86d0_level0_col1" class="col_heading level0 col1" >Unnamed: 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b86d0_row0_col0" class="data row0 col0" >제 3(당)기 2023년 12월 31일 현재</td>
#       <td id="T_b86d0_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_b86d0_row1_col0" class="data row1 col0" >제 2(전)기 2022년 12월 31일 현재</td>
#       <td id="T_b86d0_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_b86d0_row2_col0" class="data row2 col0" >재단법인 김포에프씨</td>
#       <td id="T_b86d0_row2_col1" class="data row2 col1" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_b86d0_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_b86d0_row3_col1" class="data row3 col1" >nan</td>
#     </tr>
#     <tr>
# ...

# %%
with open('spreadsheet.html', 'w', encoding='utf-8') as fo:
    fo.write(df.style.hide(axis='index').to_html())

# %%
# pip install nbconvert[webpdf]
